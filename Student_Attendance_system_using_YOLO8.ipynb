# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 10.4 MB/s eta 0:00:00
# ...

# %%
# !pip install git+https://github.com/ultralytics/ultralytics.git@main
# Out:
# ...
#   Cloning https://github.com/ultralytics/ultralytics.git (to revision main) to /tmp/pip-req-build-g28fh8xe
#   Running command git clone --filter=blob:none --quiet https://github.com/ultralytics/ultralytics.git /tmp/pip-req-build-g28fh8xe
#   Resolved https://github.com/ultralytics/ultralytics.git to commit 70c400ee158fc52361e6d38e4b93f55fff21edd7
#   Preparing metadata (setup.py) ... done
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.yaml')
model = YOLO('yolov8n.pt')
model = YOLO('yolov8n.yaml').load('yolov8n.pt')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/attendance/Student attendance.v1i.yolov8.zip' -d '/content/drive/MyDrive/attendance/extract'
# Out:
# Archive:  /content/drive/MyDrive/attendance/Student attendance.v1i.yolov8.zip
#  extracting: /content/drive/MyDrive/attendance/extract/README.dataset.txt
#  extracting: /content/drive/MyDrive/attendance/extract/README.roboflow.txt
#  extracting: /content/drive/MyDrive/attendance/extract/data.yaml
#    creating: /content/drive/MyDrive/attendance/extract/test/
#    creating: /content/drive/MyDrive/attendance/extract/test/images/
#  extracting: /content/drive/MyDrive/attendance/extract/test/images/IMG20230411102056_jpg.rf.ead248198409b20e89330a9836280590.jpg
#  extracting: /content/drive/MyDrive/attendance/extract/test/images/IMG20230411102113_01_jpg.rf.69e53b6bbf3540c60831035f061efabc.jpg
#  extracting: /content/drive/MyDrive/attendance/extract/test/images/IMG20230411102127_jpg.rf.03d75b5f2668e04fd6c8fe4c963213da.jpg
#  extracting: /content/drive/MyDrive/attendance/extract/test/images/IMG20230411102147_jpg.rf.5b4e907bcf97d73d611fa5f935bf1c66.jpg
# ...

# %%
results = model.train(data='/content/drive/MyDrive/attendance/extract/data.yaml',epochs=10, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO('/content/runs/detect/train/weights/last.pt')
results = model.train(resume=True)

# %%
import ultralytics
ultralytics.utils.metrics.ConfusionMatrix
# Out:
# ultralytics.utils.metrics.ConfusionMatrix

# %%
metrics = model.val()  # no arguments needed, dataset and settings remembered
 # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3008378 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/attendance/extract/valid/labels.cache... 139 images, 0 backgrounds, 0 corrupt: 100%|██████████| 139/139 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 9/9 [00:05<00:00,  1.76it/s]
#                    all        139        139      0.985      0.984      0.984      0.908
#     Al Vincent C Acain        139         12      0.993          1      0.995       0.88
#            Alma T Ruiz        139          6      0.987          1      0.995      0.995
#     Anfernee C Seprado        139         11      0.992          1      0.995      0.879
#      Angelika A Guadez        139         10      0.993          1      0.995      0.897
# ...

# %%
metrics.box.maps
# Out:
# array([    0.88045,       0.995,     0.87882,      0.8966,     0.86288,     0.98601,     0.95934,     0.97101,     0.83076,     0.81418,     0.93314,     0.90532,     0.91185,     0.88978])

# %%
import IPython
from IPython.display import Image

# %%
model.predict('/content/drive/MyDrive/student 1/expo',save=True,imgsz=320,conf=0.5)
# Out:
# image 1/1 /content/drive/MyDrive/attendance/extract/valid/images/IMG20230411102102_jpg.rf.1a4994f6e5b919e51b8295ac36dbd889.jpg: 320x320 1 Al Vincent C Acain, 12.2ms
# Speed: 1.1ms preprocess, 12.2ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/train3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Al Vincent C Acain', 1: 'Alma T Ruiz', 2: 'Anfernee C Seprado', 3: 'Angelika A Guadez', 4: 'Antoniette M Refulle', 5: 'Carla E Dumas', 6: 'James C Baron', 7: 'Jane M Ludivese', 8: 'Jay V Retaga', 9: 'Jee Hannah C Cabasag', 10: 'Jonalyn M Calimbo', 11: 'Joshua V Almodiel', 12: 'Mark Anthony B Nazareno', 13: 'Queenie Mae A Carnicer'}
#  orig_img: array([[[101,  89,  95],
#          [102,  90,  96],
#          [103,  91,  97],
#          ...,
#          [124, 152, 159],
#          [126, 155, 162],
#          [128, 157, 164]],
#
# ...
